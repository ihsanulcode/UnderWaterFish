# %% [markdown]
# # Counts the number of images in each folder

# %%
import os

def count_images(folder_name):
  image_count = 0
  for filename in os.listdir(folder_name):
    # Check if it's an image file
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
      image_count += 1
  return image_count

# Count images in Fish folder
fish_image_count = count_images("Dataset/Fish")

# Count images in Not Fish folder
not_fish_image_count = count_images("Dataset/Not Fish")

print(f"Number of images in Fish folder: {fish_image_count}")
print(f"Number of images in Not Fish folder: {not_fish_image_count}")
# Out:
# Number of images in Fish folder: 1380
# Number of images in Not Fish folder: 2879

# %% [markdown]
# # Rename Images

# %%
def rename_images(folder_name, prefix):
  count = 1
  for filename in os.listdir(folder_name):
    # Check if it's an image file and modify extensions as needed
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
      # Create new filename with prefix and sequential number
      new_filename = f"{prefix}_image_{count}{os.path.splitext(filename)[1]}"
      # Rename the file
      os.rename(os.path.join(folder_name, filename), os.path.join(folder_name, new_filename))
      count += 1

# Rename fish images
rename_images("Dataset/Fish", "fish")

# Rename non-fish images
rename_images("Dataset/Not Fish", "not_fish")

print("Images renamed successfully!")
# Out:
# Images renamed successfully!

# %% [markdown]
# # Split Dataset and Manage Folders

# %%
import os
import shutil
import random

# Set the paths
dataset_dir = 'Dataset'
fish_dir = os.path.join(dataset_dir, 'Fish')
not_fish_dir = os.path.join(dataset_dir, 'Not Fish')

train_dir = os.path.join(dataset_dir, 'Train')
test_dir = os.path.join(dataset_dir, 'Test')

# Create Train and Test directories
os.makedirs(os.path.join(train_dir, 'Fish'), exist_ok=True)
os.makedirs(os.path.join(train_dir, 'Not Fish'), exist_ok=True)
os.makedirs(os.path.join(test_dir, 'Fish'), exist_ok=True)
os.makedirs(os.path.join(test_dir, 'Not Fish'), exist_ok=True)

# Function to split the dataset
def split_dataset(source_dir, train_dir, test_dir, split_ratio=0.8):
    all_files = os.listdir(source_dir)
    random.shuffle(all_files)
    split_point = int(len(all_files) * split_ratio)
    train_files = all_files[:split_point]
    test_files = all_files[split_point:]

    for file_name in train_files:
        src_path = os.path.join(source_dir, file_name)
        dst_path = os.path.join(train_dir, file_name)
        shutil.copy(src_path, dst_path)

    for file_name in test_files:
        src_path = os.path.join(source_dir, file_name)
        dst_path = os.path.join(test_dir, file_name)
        shutil.copy(src_path, dst_path)

# Split Fish images
split_dataset(fish_dir, os.path.join(train_dir, 'Fish'), os.path.join(test_dir, 'Fish'))

# Split Not Fish images
split_dataset(not_fish_dir, os.path.join(train_dir, 'Not Fish'), os.path.join(test_dir, 'Not Fish'))

print("Dataset split completed!")
# Out:
# Dataset split completed!

# %% [markdown]
# # Merge folders

# %%
import os
import shutil

def merge_images(source_dirs, target_dir):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    for source_dir in source_dirs:
        for filename in os.listdir(source_dir):
            source_file = os.path.join(source_dir, filename)
            if os.path.isfile(source_file):
                shutil.move(source_file, target_dir)
        # Remove the source directory after all files have been moved
        shutil.rmtree(source_dir)

# Paths to the train and test directories
train_fish = 'Dataset/Train/Fish'
train_not_fish = 'Dataset/Train/Not Fish'
train_target = 'Dataset/Train'

test_fish = 'Dataset/Test/Fish'
test_not_fish = 'Dataset/Test/Not Fish'
test_target = 'Dataset/Test'

# Merge train images and delete source folders
merge_images([train_fish, train_not_fish], train_target)

# Merge test images and delete source folders
merge_images([test_fish, test_not_fish], test_target)
# Out:
# Moved: Dataset/Train/Fish\fish_image_1.jpg to Dataset/Train
# Moved: Dataset/Train/Fish\fish_image
jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2717.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2718.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2719.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2723.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2727.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_273.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2730.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2731.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2734.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2735.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2736.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_274.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2741.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2746.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2747.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2749.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2751.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2755.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2759.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_277.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2770.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2773.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2778.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2786.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2788.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2792.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_280.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2800.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2806.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2811.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2812.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2813.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2820.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2822.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2824.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2826.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_283.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2830.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2831.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_284.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2844.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2849.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2850.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2851.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2855.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_286.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2861.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2867.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_2869.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_287.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_300.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_301.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_310.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_323.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_337.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_339.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_345.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_347.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_349.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_35.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_350.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_351.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_352.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_353.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_354.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_364.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_367.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_371.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_376.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_378.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_381.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_388.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_393.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_398.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_403.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_406.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_414.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_42.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_433.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_436.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_437.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_441.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_442.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_45.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_452.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_472.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_479.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_48.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_485.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_487.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_488.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_493.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_497.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_498.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_500.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_504.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_507.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_511.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_514.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_518.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_520.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_521.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_522.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_530.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_536.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_540.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_546.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_547.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_551.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_560.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_562.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_563.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_566.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_579.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_580.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_581.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_583.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_589.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_592.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_593.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_60.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_601.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_602.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_604.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_605.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_614.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_623.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_627.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_64.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_642.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_648.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_649.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_650.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_656.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_657.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_66.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_666.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_667.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_67.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_671.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_675.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_683.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_698.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_7.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_701.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_702.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_706.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_71.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_718.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_72.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_726.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_728.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_729.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_731.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_734.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_74.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_743.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_748.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_750.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_753.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_759.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_760.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_766.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_769.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_772.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_775.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_792.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_794.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_799.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_800.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_81.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_814.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_816.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_823.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_827.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_840.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_842.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_843.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_847.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_848.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_855.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_859.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_861.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_865.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_899.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_900.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_903.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_913.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_916.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_917.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_918.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_929.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_931.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_940.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_941.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_944.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_947.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_948.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_949.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_953.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_96.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_960.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_961.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_962.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_967.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_972.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_981.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_984.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_989.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_990.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_992.jpg to Dataset/Test
# Moved: Dataset/Test/Not Fish\not_fish_image_998.jpg to Dataset/Test
# Deleted folder: Dataset/Test/Not Fish

# %% [markdown]
# # Process Train set and labels

# %%
import pandas as pd
import numpy as np
import os

Id = []
for dirname, _, filenames in os.walk('Dataset/Train/'):
    for filename in filenames:
        Id.append(os.path.join(dirname, filename))
Id[:10]
# Out:
# ['Dataset/Train/fish_image_1.jpg',
#  'Dataset/Train/fish_image_10.jpg',
#  'Dataset/Train/fish_image_1000.jpg',
#  'Dataset/Train/fish_image_1001.jpg',
#  'Dataset/Train/fish_image_1002.jpg',
#  'Dataset/Train/fish_image_1004.jpg',
#  'Dataset/Train/fish_image_1005.jpg',
#  'Dataset/Train/fish_image_1006.jpg',
#  'Dataset/Train/fish_image_1008.jpg',
#  'Dataset/Train/fish_image_1009.jpg']

# %%
# Convert image id's to pandas dataframe
train = pd.DataFrame().assign(filename=Id)
train.head()
# Out:
#                             filename
# 0     Dataset/Train/fish_image_1.jpg
# 1    Dataset/Train/fish_image_10.jpg
# 2  Dataset/Train/fish_image_1000.jpg
# 3  Dataset/Train/fish_image_1001.jpg
# 4  Dataset/Train/fish_image_1002.jpg

# %%
train.tail()
# Out:
#                                   filename
# 3402  Dataset/Train/not_fish_image_994.jpg
# 3403  Dataset/Train/not_fish_image_995.jpg
# 3404  Dataset/Train/not_fish_image_996.jpg
# 3405  Dataset/Train/not_fish_image_997.jpg
# 3406  Dataset/Train/not_fish_image_999.jpg

# %%
# Add new column 'label' and process labels for images
train['label'] = train['filename']

for i in range(len(train)):
    if 'fish' in train['filename'][i]:
        train['label'][i] = 'fish'
    if 'not_fish' in train['filename'][i]:
        train['label'][i] = 'not_fish'

# %%
train.head()
# Out:
#                             filename label
# 0     Dataset/Train/fish_image_1.jpg  fish
# 1    Dataset/Train/fish_image_10.jpg  fish
# 2  Dataset/Train/fish_image_1000.jpg  fish
# 3  Dataset/Train/fish_image_1001.jpg  fish
# 4  Dataset/Train/fish_image_1002.jpg  fish

# %%
train.tail()
# Out:
#                                   filename     label
# 3402  Dataset/Train/not_fish_image_994.jpg  not_fish
# 3403  Dataset/Train/not_fish_image_995.jpg  not_fish
# 3404  Dataset/Train/not_fish_image_996.jpg  not_fish
# 3405  Dataset/Train/not_fish_image_997.jpg  not_fish
# 3406  Dataset/Train/not_fish_image_999.jpg  not_fish

# %%
train['label'].value_counts()
# Out:
# label
# not_fish    2303
# fish        1104
# Name: count, dtype: int64

# %% [markdown]
# # Process Test set and labels

# %%
Id = []
for dirname, _, filenames in os.walk('Dataset/Test/'):
    for filename in filenames:
        Id.append(os.path.join(dirname, filename))
Id[:10]
# Out:
# ['Dataset/Test/fish_image_100.jpg',
#  'Dataset/Test/fish_image_1003.jpg',
#  'Dataset/Test/fish_image_1007.jpg',
#  'Dataset/Test/fish_image_1015.jpg',
#  'Dataset/Test/fish_image_1018.jpg',
#  'Dataset/Test/fish_image_1027.jpg',
#  'Dataset/Test/fish_image_1030.jpg',
#  'Dataset/Test/fish_image_1033.jpg',
#  'Dataset/Test/fish_image_1036.jpg',
#  'Dataset/Test/fish_image_1038.jpg']

# %%
# Convert image id's to pandas dataframe
test = pd.DataFrame().assign(filename=Id)
test.head()
# Out:
#                            filename
# 0   Dataset/Test/fish_image_100.jpg
# 1  Dataset/Test/fish_image_1003.jpg
# 2  Dataset/Test/fish_image_1007.jpg
# 3  Dataset/Test/fish_image_1015.jpg
# 4  Dataset/Test/fish_image_1018.jpg

# %%
test.tail()
# Out:
#                                 filename
# 847  Dataset/Test/not_fish_image_984.jpg
# 848  Dataset/Test/not_fish_image_989.jpg
# 849  Dataset/Test/not_fish_image_990.jpg
# 850  Dataset/Test/not_fish_image_992.jpg
# 851  Dataset/Test/not_fish_image_998.jpg

# %%
# Add new column 'label' and process labels for images
test['label'] = test['filename']

for i in range(len(test)):
    if 'fish' in test['filename'][i]:
        test['label'][i] = 'fish'
    if 'not_fish' in test['filename'][i]:
        test['label'][i] = 'not_fish'

# %%
test.head()
# Out:
#                            filename label
# 0   Dataset/Test/fish_image_100.jpg  fish
# 1  Dataset/Test/fish_image_1003.jpg  fish
# 2  Dataset/Test/fish_image_1007.jpg  fish
# 3  Dataset/Test/fish_image_1015.jpg  fish
# 4  Dataset/Test/fish_image_1018.jpg  fish

# %%
test.tail()
# Out:
#                                 filename     label
# 847  Dataset/Test/not_fish_image_984.jpg  not_fish
# 848  Dataset/Test/not_fish_image_989.jpg  not_fish
# 849  Dataset/Test/not_fish_image_990.jpg  not_fish
# 850  Dataset/Test/not_fish_image_992.jpg  not_fish
# 851  Dataset/Test/not_fish_image_998.jpg  not_fish

# %%
test['label'].value_counts()
# Out:
# label
# not_fish    576
# fish        276
# Name: count, dtype: int64

# %%
# Save train and test dataframe as csv for future use
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
